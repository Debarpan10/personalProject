# %%
pip install pyautogui
# Out:
# ...
#
# ...
#                                               0.0/61.2 kB ? eta -:--:--
#      ---------------------------------        51.2/61.2 kB 2.6 MB/s eta 0:00:01
#      ---------------------------------------- 61.2/61.2 kB 1.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#                                               0.0/168.2 kB ? eta -:--:--
# ...

# %%
import pyautogui as auto
import time

while True:
    auto.write("Happy Diwali vai")
    auto.press('enter')
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 auto.write("Happy Diwali vai")
#       6 auto.press('enter')
# ----> 7 time.sleep(1)
#
# KeyboardInterrupt:

# %%
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai

Happy Diwali vaiHappy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
Happy Diwali vai
